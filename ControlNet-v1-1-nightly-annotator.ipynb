# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/ControlNet-v1-1-nightly-colab/blob/main/ControlNet-v1-1-nightly-annotator.ipynb)

# %%
# %cd /content
# !git clone https://github.com/lllyasviel/ControlNet-v1-1-nightly
# !pip install -q gradio einops transformers open_clip_torch pytorch_lightning==1.7.7 omegaconf xformers==0.0.18 triton==2.0.0 basicsr safetensors

# %cd /content/ControlNet-v1-1-nightly
# !sed -i "s/block.launch(server_name='0.0.0.0')/block.launch(server_name='0.0.0.0', share=True)/g" gradio_annotator.py
# !python gradio_annotator.py
